# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\rites\Downloads\Walmart (1).csv")

# %%
df.head()
# Out:
#          Order ID  Order Date   Ship Date    Customer Name        Country  \
# 0  CA-2013-138688  13-06-2013  17-06-2013  Darrin Van Huff  United States
# 1  CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 2  CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 3  CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 4  CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
#
#           City       State     Category  \
# 0  Los Angeles  California       Labels
# 1  Los Angeles  California  Furnishings
# 2  Los Angeles  California          Art
# 3  Los Angeles  California       Phones
# 4  Los Angeles  California      Binders
#
#                                         Product Name   Sales  Quantity  Profit
# 0  Self-Adhesive Address Labels for Typewriters b...   14.62       2.0    6.87
# 1  Eldon Expressions Wood and Plastic Desk Access...   48.86       7.0   14.17
# 2                                         Newell 322    7.28       4.0    1.97
# 3                     Mitel 5320 IP Phone VoIP phone  907.15       4.0   90.72
# 4  DXL Angle-View Binders with Locking Rings by S...   18.50       3.0    5.78

# %%
df.tail()
# Out:
#             Order ID  Order Date   Ship Date Customer Name        Country  \
# 3198  CA-2013-125794  30-09-2013  04-10-2013  Maris LaWare  United States
# 3199  CA-2014-121258  27-02-2014  04-03-2014   Dave Brooks  United States
# 3200  CA-2014-121258  27-02-2014  04-03-2014   Dave Brooks  United States
# 3201  CA-2014-121258  27-02-2014  04-03-2014   Dave Brooks  United States
# 3202  CA-2014-119914  05-05-2014  10-05-2014  Chris Cortes  United States
#
#              City       State     Category  \
# 3198  Los Angeles  California  Accessories
# 3199   Costa Mesa  California  Furnishings
# 3200   Costa Mesa  California       Phones
# 3201   Costa Mesa  California        Paper
# 3202  Westminster  California   Appliances
#
#                                            Product Name   Sales  Quantity  \
# 3198  Memorex Mini Travel Drive 64 GB USB 2.0 Flash ...   36.24       1.0
# 3199  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.96       2.0
# 3200                              Aastra 57i VoIP phone  258.58       2.0
# 3201  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.60       4.0
# 3202  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.16       2.0
#
#       Profit
# 3198   15.22
# 3199   15.63
# 3200   19.39
# 3201   13.32
# 3202   72.95

# %%
df.describe()
# Out:
#               Sales     Quantity       Profit
# count   3203.000000  3203.000000  3203.000000
# mean     226.493266     3.828910    33.849138
# std      524.876911     2.260947   174.109155
# min        0.990000     1.000000 -3399.980000
# 25%       19.440000     2.000000     3.850000
# 50%       60.840000     3.000000    11.170000
# 75%      215.810000     5.000000    33.000000
# max    13999.960000    14.000000  6719.980000

# %%
df.shape
# Out:
# (3203, 12)

# %%
df.size
# Out:
# 38436

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Customer Name', 'Country',
#        'City', 'State', 'Category', 'Product Name', 'Sales', 'Quantity',
#        'Profit'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3203 entries, 0 to 3202
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       3203 non-null   object
#  1   Order Date     3203 non-null   object
#  2   Ship Date      3203 non-null   object
#  3   Customer Name  3203 non-null   object
#  4   Country        3203 non-null   object
#  5   City           3203 non-null   object
#  6   State          3203 non-null   object
#  7   Category       3203 non-null   object
#  8   Product Name   3203 non-null   object
#  9   Sales          3203 non-null   float64
#  10  Quantity       3203 non-null   float64
#  11  Profit         3203 non-null   float64
# dtypes: float64(3), object(9)
# memory usage: 300.4+ KB

# %%
df.transpose()
# Out:
#                                                             0     \
# Order ID                                          CA-2013-138688
# Order Date                                            13-06-2013
# Ship Date                                             17-06-2013
# Customer Name                                    Darrin Van Huff
# Country                                            United States
# City                                                 Los Angeles
# State                                                 California
# Category                                                  Labels
# Product Name   Self-Adhesive Address Labels for Typewriters b...
# Sales                                                      14.62
# Quantity                                                     2.0
# Profit                                                      6.87
#
#                                                             1     \
# Order ID                                          CA-2011-115812
# Order Date                                            09-06-2011
# Ship Date                                             14-06-2011
# Customer Name                                    Brosina Hoffman
# Country                                            United States
# City                                                 Los Angeles
# State                                                 California
# Category                                             Furnishings
# Product Name   Eldon Expressions Wood and Plastic Desk Access...
# Sales                                                      48.86
# Quantity                                                     7.0
# Profit                                                     14.17
#
#                           2                               3     \
# Order ID        CA-2011-115812                  CA-2011-115812
# Order Date          09-06-2011                      09-06-2011
# Ship Date           14-06-2011                      14-06-2011
# Customer Name  Brosina Hoffman                 Brosina Hoffman
# Country          United States                   United States
# City               Los Angeles                     Los Angeles
# State               California                      California
# Category                   Art                          Phones
# Product Name        Newell 322  Mitel 5320 IP Phone VoIP phone
# Sales                     7.28                          907.15
# Quantity                   4.0                             4.0
# Profit                    1.97                           90.72
#
#                                                             4     \
# Order ID                                          CA-2011-115812
# Order Date                                            09-06-2011
# Ship Date                                             14-06-2011
# Customer Name                                    Brosina Hoffman
# Country                                            United States
# City                                                 Los Angeles
# State                                                 California
# Category                                                 Binders
# Product Name   DXL Angle-View Binders with Locking Rings by S...
# Sales                                                       18.5
# Quantity                                                     3.0
# Profit                                                      5.78
#
#                                            5     \
# Order ID                         CA-2011-115812
# Order Date                           09-06-2011
# Ship Date                            14-06-2011
# Customer Name                   Brosina Hoffman
# Country                           United States
# City                                Los Angeles
# State                                California
# Category                             Appliances
# Product Name   Belkin F5C206VTEL 6 Outlet Surge
# Sales                                     114.9
# Quantity                                    5.0
# Profit                                    34.47
#
#                                                    6     \
# Order ID                                 CA-2011-115812
# Order Date                                   09-06-2011
# Ship Date                                    14-06-2011
# Customer Name                           Brosina Hoffman
# Country                                   United States
# City                                        Los Angeles
# State                                        California
# Category                                         Tables
# Product Name   Chromcraft Rectangular Conference Tables
# Sales                                           1706.18
# Quantity                                            9.0
# Profit                                            85.31
#
#                                                         7     \
# Order ID                                      CA-2011-115812
# Order Date                                        09-06-2011
# Ship Date                                         14-06-2011
# Customer Name                                Brosina Hoffman
# Country                                        United States
# City                                             Los Angeles
# State                                             California
# Category                                              Phones
# Product Name   Konftel 250 Conference phone - Charcoal black
# Sales                                                 911.42
# Quantity                                                 4.0
# Profit                                                 68.36
#
#                                                       8     \
# Order ID                                    CA-2013-161389
# Order Date                                      06-12-2013
# Ship Date                                       11-12-2013
# Customer Name                                 Irene Maddox
# Country                                      United States
# City                                               Seattle
# State                                           Washington
# Category                                           Binders
# Product Name   Fellowes PB200 Plastic Comb Binding Machine
# Sales                                               407.98
# Quantity                                               3.0
# Profit                                              132.59
#
#                                      9     ...            3193  \
# Order ID                   CA-2011-167164  ...  US-2013-103674
# Order Date                     13-05-2011  ...      07-12-2013
# Ship Date                      15-05-2011  ...      11-12-2013
# Customer Name             Alejandro Grove  ...      Anne Pryor
# Country                     United States  ...   United States
# City                          West Jordan  ...     Los Angeles
# State                                Utah  ...      California
# Category                          Storage  ...           Paper
# Product Name   Fellowes Super Stor/Drawer  ...      Xerox 1977
# Sales                                55.5  ...           13.36
# Quantity                              2.0  ...             2.0
# Profit                               9.99  ...            6.41
#
#                          3194                                      3195  \
# Order ID       US-2013-103674                            US-2013-103674
# Order Date         07-12-2013                                07-12-2013
# Ship Date          11-12-2013                                11-12-2013
# Customer Name      Anne Pryor                                Anne Pryor
# Country         United States                             United States
# City              Los Angeles                               Los Angeles
# State              California                                California
# Category               Phones                                 Fasteners
# Product Name     Cisco SPA301  Alliance Big Bands Rubber Bands, 12/Pack
# Sales                  249.58                                     13.86
# Quantity                  2.0                                       7.0
# Profit                   31.2                                       0.0
#
#                                                             3196  \
# Order ID                                          US-2013-103674
# Order Date                                            07-12-2013
# Ship Date                                             11-12-2013
# Customer Name                                         Anne Pryor
# Country                                            United States
# City                                                 Los Angeles
# State                                                 California
# Category                                                 Binders
# Product Name   Avery Durable Slant Ring Binders With Label Ho...
# Sales                                                      13.38
# Quantity                                                     4.0
# Profit                                                      4.68
#
#                                             3197  \
# Order ID                          US-2013-103674
# Order Date                            07-12-2013
# Ship Date                             11-12-2013
# Customer Name                         Anne Pryor
# Country                            United States
# City                                 Los Angeles
# State                                 California
# Category                                 Binders
# Product Name   Ibico Recycled Linen-Style Covers
# Sales                                     437.47
# Quantity                                    14.0
# Profit                                    153.12
#
#                                                             3198  \
# Order ID                                          CA-2013-125794
# Order Date                                            30-09-2013
# Ship Date                                             04-10-2013
# Customer Name                                       Maris LaWare
# Country                                            United States
# City                                                 Los Angeles
# State                                                 California
# Category                                             Accessories
# Product Name   Memorex Mini Travel Drive 64 GB USB 2.0 Flash ...
# Sales                                                      36.24
# Quantity                                                     1.0
# Profit                                                     15.22
#
#                                                             3199  \
# Order ID                                          CA-2014-121258
# Order Date                                            27-02-2014
# Ship Date                                             04-03-2014
# Customer Name                                        Dave Brooks
# Country                                            United States
# City                                                  Costa Mesa
# State                                                 California
# Category                                             Furnishings
# Product Name   Tenex B1-RE Series Chair Mats for Low Pile Car...
# Sales                                                      91.96
# Quantity                                                     2.0
# Profit                                                     15.63
#
#                                 3200  \
# Order ID              CA-2014-121258
# Order Date                27-02-2014
# Ship Date                 04-03-2014
# Customer Name            Dave Brooks
# Country                United States
# City                      Costa Mesa
# State                     California
# Category                      Phones
# Product Name   Aastra 57i VoIP phone
# Sales                         258.58
# Quantity                         2.0
# Profit                         19.39
#
#                                                             3201  \
# Order ID                                          CA-2014-121258
# Order Date                                            27-02-2014
# Ship Date                                             04-03-2014
# Customer Name                                        Dave Brooks
# Country                                            United States
# City                                                  Costa Mesa
# State                                                 California
# Category                                                   Paper
# Product Name   It's Hot Message Books with Stickers, 2 3/4" x 5"
# Sales                                                       29.6
# Quantity                                                     4.0
# Profit                                                     13.32
#
#                                                             3202
# Order ID                                          CA-2014-119914
# Order Date                                            05-05-2014
# Ship Date                                             10-05-2014
# Customer Name                                       Chris Cortes
# Country                                            United States
# City                                                 Westminster
# State                                                 California
# Category                                              Appliances
# Product Name   Acco 7-Outlet Masterpiece Power Center, Wihtou...
# Sales                                                     243.16
# Quantity                                                     2.0
# Profit                                                     72.95
#
# [12 rows x 3203 columns]

# %%
df.isnull()
# Out:
#       Order ID  Order Date  Ship Date  Customer Name  Country   City  State  \
# 0        False       False      False          False    False  False  False
# 1        False       False      False          False    False  False  False
# 2        False       False      False          False    False  False  False
# 3        False       False      False          False    False  False  False
# 4        False       False      False          False    False  False  False
# ...        ...         ...        ...            ...      ...    ...    ...
# 3198     False       False      False          False    False  False  False
# 3199     False       False      False          False    False  False  False
# 3200     False       False      False          False    False  False  False
# 3201     False       False      False          False    False  False  False
# 3202     False       False      False          False    False  False  False
#
#       Category  Product Name  Sales  Quantity  Profit
# 0        False         False  False     False   False
# 1        False         False  False     False   False
# 2        False         False  False     False   False
# 3        False         False  False     False   False
# 4        False         False  False     False   False
# ...        ...           ...    ...       ...     ...
# 3198     False         False  False     False   False
# 3199     False         False  False     False   False
# 3200     False         False  False     False   False
# 3201     False         False  False     False   False
# 3202     False         False  False     False   False
#
# [3203 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# Order ID         0
# Order Date       0
# Ship Date        0
# Customer Name    0
# Country          0
# City             0
# State            0
# Category         0
# Product Name     0
# Sales            0
# Quantity         0
# Profit           0
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    3203
# dtype: int64

# %%
sales_by_category=df.groupby('Category')['Sales'].sum().sort_values(ascending=False)
print(sales_by_category)
# Out:
# Category
# Chairs         101781.36
# Phones          98684.39
# Tables          84754.60
# Storage         70532.84
# Accessories     61114.10
# Binders         55961.11
# Copiers         49749.23
# Machines        42444.14
# Bookcases       36004.18
# Appliances      30236.32
# Furnishings     30072.73
# Paper           26663.73
# Supplies        18127.12
# Art              9212.06
# Labels           5078.72
# Envelopes        4118.10
# Fasteners         923.20
# Name: Sales, dtype: float64

# %%
sales_by_category.plot(kind='bar',color='red')
plt.show()

# %%
df['Order Date']=pd.to_datetime(df['Order Date'])
df['Month']=df['Order Date'].dt.month
average_sales_per_month=df.groupby('Month')['Sales'].mean()
print(average_sales_per_month)
# Out:
# Month
# 1     266.847467
# 2     222.428571
# 3     276.234050
# 4     222.331633
# 5     229.070139
# 6     211.696605
# 7     261.987261
# 8     235.161869
# 9     186.921716
# 10    209.842862
# 11    204.813416
# 12    231.942423
# Name: Sales, dtype: float64

# %%
average_sales_per_month.plot(kind='line',color='blue',ls='--')
plt.show()

# %%
sales_by_state=df.groupby('State')['Sales'].sum().sort_values(ascending=False)
sales_by_state.plot(kind='bar',color='red')
plt.show()

# %%
sales_by_product=df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False)
sales_by_product.head().plot(kind='barh',color='yellow')
plt.show()

# %%
sales_by_month_category=df.groupby(['Month','Category'])['Sales'].sum().unstack()
plt.pcolor(sales_by_month_category,cmap='Blues')
plt.xlabel('Category')
plt.ylabel('Month')
plt.xticks(rotation=45)
plt.colorbar()
plt.show()

# %%
sales_by_customer=df.groupby('Customer Name')['Sales'].sum()
plt.scatter(sales_by_customer.head(20).index,sales_by_customer.head(20).values,c='c')
plt.xlabel('Customer')
plt.xticks(rotation=90)
plt.ylabel('Sales')
plt.show()

# %%
monthly_sales=df.groupby(pd.Grouper(key='Order Date',freq='M'))['Sales'].sum()
monthly_sales_growth=monthly_sales.pct_change()
monthly_sales_growth.plot(kind='line',ls='-.',color='orange')
plt.xlabel('Month')
plt.ylabel('Sales Growth')
plt.show()
